# %%
import pandas as pd
df = pd.read_excel('cse.xls')
df
# Out:
#     SI No.  Roll No.          Student Name  \
# 0        1  141CS101           Abishek R K
# 1        2  141CS102   Aishwarya Lakshmi S
# 2        3  141CS103           Aishwarya S
# 3        4  141CS108        Aravindkumar G
# 4        5  141CS110   Arthijayabharathi S
# 5        6  141CS112       Ashish Krishnan
# 6        7  141CS116             Athirai D
# 7        8  141CS118         Bala Ganesh M
# 8        9  141CS119         Balachander S
# 9       10  141CS121       Balamugunthan R
# 10      11  141CS122           Banupriya S
# 11      12  141CS123            Bharrani N
# 12      13  141CS126           Deepthi M S
# 13      14  141CS128        Dhanalakshmi M
# 14      15  141CS130        Dhilip Kumar S
# 15      16  141CS131          Dhinakaran P
# 16      17  141CS132              Dhivya N
# 17      18  141CS135         Geethanjali M
# 18      19  141CS137        Gokul Rajhen V
# 19      20  141CS140             Gomathi G
# 20      21  141CS147      Hemamalinimurali
# ...

# %%
df.iloc[0,1]
# Out:
# '141cs267'

# %%
df.iloc[0,1]='141cs267'

# %%
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
df1 = pd.DataFrame(df)
df1
# Out:
#     SI No.  Roll No.          Student Name  \
# 0        1  141CS101           Abishek R K
# 1        2  141CS102   Aishwarya Lakshmi S
# 2        3  141CS103           Aishwarya S
# 3        4  141CS108        Aravindkumar G
# 4        5  141CS110   Arthijayabharathi S
# 5        6  141CS112       Ashish Krishnan
# 6        7  141CS116             Athirai D
# 7        8  141CS118         Bala Ganesh M
# 8        9  141CS119         Balachander S
# 9       10  141CS121       Balamugunthan R
# 10      11  141CS122           Banupriya S
# 11      12  141CS123            Bharrani N
# 12      13  141CS126           Deepthi M S
# 13      14  141CS128        Dhanalakshmi M
# 14      15  141CS130        Dhilip Kumar S
# 15      16  141CS131          Dhinakaran P
# 16      17  141CS132              Dhivya N
# 17      18  141CS135         Geethanjali M
# 18      19  141CS137        Gokul Rajhen V
# 19      20  141CS140             Gomathi G
# 20      21  141CS147      Hemamalinimurali
# ...

# %%
#from xlutils.copy import copy
import xlrd
import xlwt
writer = ExcelWriter('cse.xls')
df1.to_excel(writer,'Sheet1')
writer.save()

# %%
df1
# Out:
#     SI No.  Roll No.          Student Name  \
# 0        1  141CS101           Abishek R K
# 1        2  141CS102   Aishwarya Lakshmi S
# 2        3  141CS103           Aishwarya S
# 3        4  141CS108        Aravindkumar G
# 4        5  141CS110   Arthijayabharathi S
# 5        6  141CS112       Ashish Krishnan
# 6        7  141CS116             Athirai D
# 7        8  141CS118         Bala Ganesh M
# 8        9  141CS119         Balachander S
# 9       10  141CS121       Balamugunthan R
# 10      11  141CS122           Banupriya S
# 11      12  141CS123            Bharrani N
# 12      13  141CS126           Deepthi M S
# 13      14  141CS128        Dhanalakshmi M
# 14      15  141CS130        Dhilip Kumar S
# 15      16  141CS131          Dhinakaran P
# 16      17  141CS132              Dhivya N
# 17      18  141CS135         Geethanjali M
# 18      19  141CS137        Gokul Rajhen V
# 19      20  141CS140             Gomathi G
# 20      21  141CS147      Hemamalinimurali
# ...

# %%
from xlutils.copy import copy
from xlrd import *
w = copy(open_workbook('cse.xls'))
w_write = w.get_sheet(0)
vijay = "345"
w_write.write(1,1,vijay)
w.save('book.xls')

# %%
pd.read_excel('book.xls')
# Out:
#     SI No.  Roll No.          Student Name  \
# 0      345  141CS101           Abishek R K
# 1        2  141CS102   Aishwarya Lakshmi S
# 2        3  141CS103           Aishwarya S
# 3        4  141CS108        Aravindkumar G
# 4        5  141CS110   Arthijayabharathi S
# 5        6  141CS112       Ashish Krishnan
# 6        7  141CS116             Athirai D
# 7        8  141CS118         Bala Ganesh M
# 8        9  141CS119         Balachander S
# 9       10  141CS121       Balamugunthan R
# 10      11  141CS122           Banupriya S
# 11      12  141CS123            Bharrani N
# 12      13  141CS126           Deepthi M S
# 13      14  141CS128        Dhanalakshmi M
# 14      15  141CS130        Dhilip Kumar S
# 15      16  141CS131          Dhinakaran P
# 16      17  141CS132              Dhivya N
# 17      18  141CS135         Geethanjali M
# 18      19  141CS137        Gokul Rajhen V
# 19      20  141CS140             Gomathi G
# 20      21  141CS147      Hemamalinimurali
# ...

# %%
from xlutils.copy import copy
from xlrd import *
w = copy(open_workbook('book.xls'))
w.get_sheet(0).write(0,0,5)
w.save('book2.xls')

# %%
pd.read_excel('book2.xls')
# Out:
#      5  345  Roll No.          Student Name  \
# 0    0    1  141CS101           Abishek R K
# 1    1    2  141CS102   Aishwarya Lakshmi S
# 2    2    3  141CS103           Aishwarya S
# 3    3    4  141CS108        Aravindkumar G
# 4    4    5  141CS110   Arthijayabharathi S
# 5    5    6  141CS112       Ashish Krishnan
# 6    6    7  141CS116             Athirai D
# 7    7    8  141CS118         Bala Ganesh M
# 8    8    9  141CS119         Balachander S
# 9    9   10  141CS121       Balamugunthan R
# 10  10   11  141CS122           Banupriya S
# 11  11   12  141CS123            Bharrani N
# 12  12   13  141CS126           Deepthi M S
# 13  13   14  141CS128        Dhanalakshmi M
# 14  14   15  141CS130        Dhilip Kumar S
# 15  15   16  141CS131          Dhinakaran P
# 16  16   17  141CS132              Dhivya N
# 17  17   18  141CS135         Geethanjali M
# 18  18   19  141CS137        Gokul Rajhen V
# 19  19   20  141CS140             Gomathi G
# ...
